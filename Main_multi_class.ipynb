# %%
# !pip install ipynb

# %%
import torch
import gc

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# 20

# %%
from ipynb.fs.full.Normalization_MultiClass_to_import import *
# Out:
# Execution time: 0.6955118179321289 seconds

# %%
from ipynb.fs.full.GeneratedDataMultiClass_to_import import *
# Out:
# Execution time: 0.03428030014038086 seconds

# %%
from ipynb.fs.full.MultiClass_to_import_maxAbsScaler_normalized import *
# Out:
# Execution time: 1.3687827587127686 seconds
# Metrics for maxAbsScaler normalized data is ready. Run 'multiclass_maxAbsScaler_LogisticRegression_metrics.main()'!
# Execution time: 1.6628870964050293 seconds
# Metrics for maxAbsScaler normalized data is ready. Run 'multiclass_maxAbsScaler_LinearRegression_metrics.main()'!
# Execution time: 2.568416118621826 seconds
# Metrics for maxAbsScaler normalized data is ready. Run 'multiclass_maxAbsScaler_Ridge_metrics.main()'!
# Execution time: 0.5628092288970947 seconds
# Metrics for maxAbsScaler normalized data is ready. Run 'multiclass_maxAbsScaler_Lasso_metrics.main()'!
# Execution time: 0.8576791286468506 seconds
# Metrics for maxAbsScaler normalized data is ready. Run 'multiclass_maxAbsScaler_ElasticNet_metrics.main()'!

# %%
from ipynb.fs.full.MultiClass_to_import_KBinsDiscretizer_normalized import *
# Out:
# Execution time: 1.2175979614257812 seconds
# Metrics for multiclass_KBinsDiscretizer_metrics.main() normalized data is ready. Run 'multiclass_KBinsDiscretizer_LogisticRegression_metrics.main()'!
# Execution time: 1.6809911727905273 seconds
# Metrics for multiclass_KBinsDiscretizer_metrics.main() normalized data is ready. Run 'multiclass_KBinsDiscretizer_LinearRegression_metrics.main()'!
# Execution time: 2.6444201469421387 seconds
# Metrics for multiclass_KBinsDiscretizer_metrics.main() normalized data is ready. Run 'multiclass_KBinsDiscretizer_Ridge_metrics.main()'!
# Execution time: 0.5682613849639893 seconds
# Metrics for multiclass_KBinsDiscretizer_metrics.main() normalized data is ready. Run 'multiclass_KBinsDiscretizer_Lasso_metrics.main()'!
# Execution time: 0.869692325592041 seconds
# Metrics for multiclass_KBinsDiscretizer_metrics.main() normalized data is ready. Run 'multiclass_KBinsDiscretizer_ElasticNet_metrics.main()'!

# %%
from ipynb.fs.full.MultiClass_to_import_function_transformer_normalized import *
# Out:
# Execution time: 1.2225744724273682 seconds
# Metrics for function_transformer normalized data is ready. Run 'multiclass_function_transformer_LogisticRegression_metrics.main()'!
# Execution time: 1.6856942176818848 seconds
# Metrics for function_transformer normalized data is ready. Run 'multiclass_function_transformer_LinearRegression_metrics.main()'!
# Execution time: 2.6394500732421875 seconds
# Metrics for function_transformer normalized data is ready. Run 'multiclass_function_transformer_Ridge_metrics.main()'!
# Execution time: 0.5629241466522217 seconds
# Metrics for function_transformer normalized data is ready. Run 'multiclass_function_transformer_Lasso_metrics.main()'!
# Execution time: 0.8869900703430176 seconds
# Metrics for function_transformer normalized data is ready. Run 'multiclass_function_transformer_ElasticNet_metrics.main()'!

# %%
from ipynb.fs.full.MultiClass_to_import_binarizer_normalized import *
# Out:
# Execution time: 1.2539377212524414 seconds
# Metrics for binarizer normalized data is ready. Run 'multiclass_binarizer_LogisticRegression_metrics.main()'!
# Execution time: 1.731278419494629 seconds
# Metrics for binarizer normalized data is ready. Run 'multiclass_binarizer_LinearRegression_metrics.main()'!
# Execution time: 2.695512056350708 seconds
# Metrics for binarizer normalized data is ready. Run 'multiclass_binarizer_Ridge_metrics.main()'!
# Execution time: 0.560922384262085 seconds
# Metrics for binarizer normalized data is ready. Run 'multiclass_binarizer_Lasso_metrics.main()'!
# Execution time: 0.8566017150878906 seconds
# Metrics for binarizer normalized data is ready. Run 'multiclass_binarizer_ElasticNet_metrics.main()'!

# %%
from ipynb.fs.full.MultiClass_to_import_robust_scaler_normalized import *
# Out:
# Execution time: 1.2372682094573975 seconds
# Metrics for robust_scaler normalized data is ready. Run 'multiclass_robust_scaler_LogisticRegression_metrics.main()'!
# Execution time: 1.7215547561645508 seconds
# Metrics for robust_scaler normalized data is ready. Run 'multiclass_robust_scaler_LinearRegression_metrics.main()'!
# Execution time: 2.633653163909912 seconds
# Metrics for robust_scaler normalized data is ready. Run 'multiclass_robust_scaler_Ridge_metrics.main()'!
# Execution time: 0.5604426860809326 seconds
# Metrics for robust_scaler normalized data is ready. Run 'multiclass_robust_scaler_Lasso_metrics.main()'!
# Execution time: 0.8600332736968994 seconds
# Metrics for robust_scaler normalized data is ready. Run 'multiclass_robust_scaler_ElasticNet_metrics.main()'!

# %%
from ipynb.fs.full.MultiClass_to_import_standard_scaler_normalized import *
# Out:
# Execution time: 0.636803150177002 seconds
# Execution time: 0.03201103210449219 seconds
# Execution time: 1.37898850440979 seconds
# Metrics for standard_scaler normalized data is ready. Run 'multiclass_standard_scaler_LogisticRegression_metrics.main()'!
# Execution time: 1.7261323928833008 seconds
# Metrics for standard_scaler normalized data is ready. Run 'multiclass_standard_scaler_LinearRegression_metrics.main()'!
# Execution time: 2.6259520053863525 seconds
# Metrics for standard_scaler normalized data is ready. Run 'multiclass_standard_scaler_Ridge_metrics.main()'!
# Execution time: 0.6063122749328613 seconds
# Metrics for standard_scaler normalized data is ready. Run 'multiclass_standard_scaler_Lasso_metrics.main()'!
# Execution time: 0.8596866130828857 seconds
# Metrics for standard_scaler normalized data is ready. Run 'multiclass_standard_scaler_ElasticNet_metrics.main()'!

# %%
import os
os._exit(00)

# %%
from ipynb.fs.full.MultiClass_to_import_MinMaxScaler_normalized import *
# Out:
# Execution time: 1.306837797164917 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'multiclass_MinMaxScaler_LogisticRegression_metrics.main()'!
# Execution time: 1.6763594150543213 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'multiclass_MinMaxScaler_LinearRegression_metrics.main()'!
# Execution time: 2.6228511333465576 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'multiclass_MinMaxScaler_Ridge_metrics.main()'!
# Execution time: 0.5659775733947754 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'multiclass_MinMaxScaler_Lasso_metrics.main()'!
# Execution time: 0.8813660144805908 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'multiclass_MinMaxScaler_ElasticNet_metrics.main()'!

# %%
from ipynb.fs.full.MultiClass_to_import_normalizer_normalized import *
# Out:
# Execution time: 1.193713903427124 seconds
# Metrics for normalizer normalized data is ready. Run 'multiclass_normalizer_LogisticRegression_metrics.main()'!
# Execution time: 1.6929044723510742 seconds
# Metrics for normalizer normalized data is ready. Run 'multiclass_normalizer_LinearRegression_metrics.main()'!
# Execution time: 2.651218891143799 seconds
# Metrics for normalizer normalized data is ready. Run 'multiclass_normalizer_Ridge_metrics.main()'!
# Execution time: 0.5540175437927246 seconds
# Metrics for normalizer normalized data is ready. Run 'multiclass_normalizer_Lasso_metrics.main()'!
# Execution time: 0.8521394729614258 seconds
# Metrics for normalizer normalized data is ready. Run 'multiclass_normalizer_ElasticNet_metrics.main()'!

# %%
from ipynb.fs.full.MultiClass_to_import_not_normalized import *
# Out:
# Execution time: 4.166870594024658 seconds
# Metrics for not normalized data is ready. Run 'multiclass_LogisticRegression_metrics.main()'!
# Execution time: 2.8265953063964844 seconds
# Metrics for not normalized data is ready. Run 'multiclass_LinearRegression_metrics.main()'!
# Execution time: 2.6826441287994385 seconds
# Metrics for not normalized data is ready. Run 'multiclass_Ridge_metrics.main()'!
# Execution time: 0.5895671844482422 seconds
# Metrics for not normalized data is ready. Run 'multiclass_Lasso_metrics.main()'!
# Execution time: 1.5238137245178223 seconds
# Metrics for not normalized data is ready. Run 'multiclass_ElasticNet_metrics.main()'!
